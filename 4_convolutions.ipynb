# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.019285
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.696954
# Minibatch accuracy: 37.5%
# Validation accuracy: 48.7%
# Minibatch loss at step 100: 0.560466
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.9%
# Minibatch loss at step 150: 0.484849
# Minibatch accuracy: 93.8%
# Validation accuracy: 75.0%
# Minibatch loss at step 200: 0.544467
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 250: 1.307465
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.1%
# Minibatch loss at step 300: 0.816255
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 350: 0.935395
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 400: 1.279940
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 450: 0.590867
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 500: 0.484792
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 550: 0.119280
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.6%
# Minibatch loss at step 600: 0.376400
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 650: 0.338570
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 700: 0.700716
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 750: 0.282587
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 800: 0.931289
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 850: 0.661143
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 900: 0.436847
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 950: 0.118114
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 1000: 0.242386
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Test accuracy: 89.1%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden = tf.nn.max_pool(hidden, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'SAME')
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden = tf.nn.max_pool(hidden, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'SAME')
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.544411
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.319788
# Minibatch accuracy: 6.2%
# Validation accuracy: 13.3%
# Minibatch loss at step 100: 1.728831
# Minibatch accuracy: 37.5%
# Validation accuracy: 41.5%
# Minibatch loss at step 150: 0.961047
# Minibatch accuracy: 68.8%
# Validation accuracy: 67.4%
# Minibatch loss at step 200: 0.659611
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.0%
# Minibatch loss at step 250: 1.476114
# Minibatch accuracy: 56.2%
# Validation accuracy: 73.0%
# Minibatch loss at step 300: 0.773400
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.4%
# Minibatch loss at step 350: 1.036982
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.6%
# Minibatch loss at step 400: 1.131140
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.5%
# Minibatch loss at step 450: 0.746564
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.9%
# Minibatch loss at step 500: 0.417154
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 550: 0.137856
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 600: 0.523593
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 650: 0.413809
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 700: 0.649267
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 750: 0.316358
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 800: 0.827050
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 850: 0.825358
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 900: 0.570712
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 950: 0.151696
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 1000: 0.219050
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.2%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 32
patch_size = 5
depth = 32
num_hidden = 128

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)

  keep_prob = tf.placeholder(tf.float32)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden = tf.nn.max_pool(hidden, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'SAME')
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden = tf.nn.max_pool(hidden, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'SAME')
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    hidden = tf.nn.dropout(hidden, keep_prob)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(model(tf_train_dataset))
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 4001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob: 0.5}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    if (step % 100 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob: 1.0}
      print('Minibatch accuracy: %.1f%%' % accuracy(train_prediction.eval(feed_dict = feed_dict), batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(feed_dict={keep_prob: 1.0}), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(feed_dict={keep_prob: 1.0}), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 7.471056
# Minibatch accuracy: 21.9%
# Validation accuracy: 13.5%
# Minibatch loss at step 100: 1.258710
# Minibatch accuracy: 78.1%
# Validation accuracy: 72.0%
# Minibatch loss at step 200: 1.742871
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.6%
# Minibatch loss at step 300: 0.582550
# Minibatch accuracy: 96.9%
# Validation accuracy: 79.5%
# Minibatch loss at step 400: 0.818601
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 500: 0.961522
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.3%
# Minibatch loss at step 600: 0.524206
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.5%
# Minibatch loss at step 700: 1.034620
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.6%
# Minibatch loss at step 800: 0.515909
# Minibatch accuracy: 96.9%
# Validation accuracy: 82.9%
# Minibatch loss at step 900: 0.788503
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.8%
# Minibatch loss at step 1000: 0.523067
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.3%
# Minibatch loss at step 1100: 0.822703
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 1200: 0.777548
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.7%
# Minibatch loss at step 1300: 0.614630
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 1400: 0.201674
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.1%
# Minibatch loss at step 1500: 0.369967
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.1%
# Minibatch loss at step 1600: 0.400780
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.8%
# Minibatch loss at step 1700: 0.604550
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 1800: 0.253865
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.6%
# Minibatch loss at step 1900: 0.375961
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 2000: 0.848185
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.0%
# Minibatch loss at step 2100: 0.381451
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.3%
# Minibatch loss at step 2200: 0.524803
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 2300: 0.504026
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 2400: 0.704605
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.4%
# Minibatch loss at step 2500: 0.952914
# Minibatch accuracy: 71.9%
# Validation accuracy: 86.5%
# Minibatch loss at step 2600: 0.809031
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 2700: 0.414440
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 2800: 0.356434
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# Minibatch loss at step 2900: 0.450767
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.9%
# Minibatch loss at step 3000: 0.304659
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.7%
# Minibatch loss at step 3100: 0.460453
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.8%
# Minibatch loss at step 3200: 0.436050
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# Minibatch loss at step 3300: 0.983125
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 3400: 0.524313
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 3500: 0.710544
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 3600: 0.310994
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 3700: 0.353601
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 3800: 0.919016
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.4%
# Minibatch loss at step 3900: 0.769191
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.1%
# Minibatch loss at step 4000: 0.568109
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Test accuracy: 93.7%

# %% [markdown]
# Minibatch loss at step 4000: 0.568109
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.4%
# Test accuracy: 93.7%

# %%
batch_size = 32
patch_size = 5
depth = 32
num_hidden = 128

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)

  keep_prob = tf.placeholder(tf.float32)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden = tf.nn.max_pool(hidden, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'SAME')
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden = tf.nn.max_pool(hidden, ksize = [1, 2, 2, 1], strides = [1, 2, 2, 1], padding = 'SAME')
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    hidden = tf.nn.dropout(hidden, keep_prob)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(model(tf_train_dataset))
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 16001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob: 0.5}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    if (step % 100 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob: 1.0}
      print('Minibatch accuracy: %.1f%%' % accuracy(train_prediction.eval(feed_dict = feed_dict), batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(feed_dict={keep_prob: 1.0}), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(feed_dict={keep_prob: 1.0}), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 6.855901
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.5%
# Minibatch loss at step 100: 1.111650
# Minibatch accuracy: 84.4%
# Validation accuracy: 72.0%
# Minibatch loss at step 200: 1.180758
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 300: 0.562926
# Minibatch accuracy: 96.9%
# Validation accuracy: 81.0%
# Minibatch loss at step 400: 1.097594
# Minibatch accuracy: 90.6%
# Validation accuracy: 81.9%
# Minibatch loss at step 500: 0.980465
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.2%
# Minibatch loss at step 600: 0.416382
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.6%
# Minibatch loss at step 700: 0.955136
# Minibatch accuracy: 78.1%
# Validation accuracy: 82.7%
# Minibatch loss at step 800: 0.465390
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.7%
# Minibatch loss at step 900: 0.699457
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 1000: 0.423237
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.0%
# Minibatch loss at step 1100: 0.668030
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.6%
# Minibatch loss at step 1200: 0.681667
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.5%
# Minibatch loss at step 1300: 0.719206
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 1400: 0.263790
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 1500: 0.184007
# Minibatch accuracy: 96.9%
# Validation accuracy: 84.5%
# Minibatch loss at step 1600: 0.572847
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.5%
# Minibatch loss at step 1700: 0.747651
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 1800: 0.237824
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.3%
# Minibatch loss at step 1900: 0.572570
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.6%
# Minibatch loss at step 2000: 0.687761
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.8%
# Minibatch loss at step 2100: 0.287267
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 2200: 0.432221
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 2300: 0.266744
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.2%
# Minibatch loss at step 2400: 0.545862
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 2500: 0.916306
# Minibatch accuracy: 71.9%
# Validation accuracy: 86.5%
# Minibatch loss at step 2600: 0.902767
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.6%
# Minibatch loss at step 2700: 0.296241
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.3%
# Minibatch loss at step 2800: 0.319796
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# Minibatch loss at step 2900: 0.539690
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 3000: 0.300618
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 3100: 0.295451
# Minibatch accuracy: 96.9%
# Validation accuracy: 86.6%
# Minibatch loss at step 3200: 0.441230
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 3300: 0.642021
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 3400: 0.608933
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# Minibatch loss at step 3500: 0.670840
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.2%
# Minibatch loss at step 3600: 0.285245
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 3700: 0.332851
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 3800: 0.783204
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 3900: 0.701321
# Minibatch accuracy: 78.1%
# Validation accuracy: 87.7%
# Minibatch loss at step 4000: 0.576624
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.1%
# Minibatch loss at step 4100: 0.222399
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.7%
# Minibatch loss at step 4200: 0.619610
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.5%
# Minibatch loss at step 4300: 0.409732
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 4400: 0.413227
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 4500: 0.533394
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.7%
# Minibatch loss at step 4600: 0.581693
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.6%
# Minibatch loss at step 4700: 0.579785
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.9%
# Minibatch loss at step 4800: 0.535356
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 4900: 0.620034
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.9%
# Minibatch loss at step 5000: 0.258570
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 5100: 0.566832
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.4%
# Minibatch loss at step 5200: 0.343269
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 5300: 0.279474
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 5400: 0.721203
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 5500: 0.669651
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 5600: 0.965015
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 5700: 0.368507
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 5800: 0.521095
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.4%
# Minibatch loss at step 5900: 0.357455
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 6000: 0.468190
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.4%
# Minibatch loss at step 6100: 0.074997
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 6200: 0.292220
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 6300: 0.318294
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.3%
# Minibatch loss at step 6400: 0.371164
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 6500: 0.561545
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.3%
# Minibatch loss at step 6600: 0.481941
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.1%
# Minibatch loss at step 6700: 0.207640
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.4%
# Minibatch loss at step 6800: 0.292476
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.6%
# Minibatch loss at step 6900: 0.452001
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 7000: 0.348446
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.6%
# Minibatch loss at step 7100: 0.535485
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 7200: 0.433485
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 7300: 0.541006
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 7400: 0.825264
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.5%
# Minibatch loss at step 7500: 0.286477
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 7600: 0.215118
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.5%
# Minibatch loss at step 7700: 0.443259
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 7800: 0.111744
# Minibatch accuracy: 96.9%
# Validation accuracy: 88.7%
# Minibatch loss at step 7900: 0.347097
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 8000: 0.278816
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 8100: 0.502431
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 8200: 0.163689
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 8300: 0.368421
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Minibatch loss at step 8400: 0.561661
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.8%
# Minibatch loss at step 8500: 0.489890
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 8600: 0.635615
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.0%
# Minibatch loss at step 8700: 0.758926
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 8800: 0.600434
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.1%
# Minibatch loss at step 8900: 0.682063
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.8%
# Minibatch loss at step 9000: 0.402313
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.0%
# Minibatch loss at step 9100: 0.690158
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 9200: 0.094016
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# Minibatch loss at step 9300: 0.279222
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Minibatch loss at step 9400: 0.493361
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 9500: 0.155063
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
# Minibatch loss at step 9600: 0.890131
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.0%
# Minibatch loss at step 9700: 0.556130
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 9800: 0.605286
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
# Minibatch loss at step 9900: 0.689898
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.1%
# Minibatch loss at step 10000: 0.247417
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 10100: 0.264412
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 10200: 0.538519
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 10300: 0.505317
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 10400: 0.709947
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 10500: 0.436369
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 10600: 0.462594
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.2%
# Minibatch loss at step 10700: 0.916873
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 10800: 0.431790
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 10900: 0.147102
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.0%
# Minibatch loss at step 11000: 0.644327
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.2%
# Minibatch loss at step 11100: 0.307897
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# Minibatch loss at step 11200: 0.573999
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 11300: 0.154023
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
# Minibatch loss at step 11400: 0.503728
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.3%
# Minibatch loss at step 11500: 0.721235
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 11600: 0.183837
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.3%
# Minibatch loss at step 11700: 0.541799
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.3%
# Minibatch loss at step 11800: 0.548669
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 11900: 0.431765
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 12000: 0.285282
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 12100: 0.732054
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 12200: 0.421432
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 12300: 0.573334
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 12400: 0.430476
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Minibatch loss at step 12500: 0.191508
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 12600: 0.797115
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 12700: 0.216436
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 12800: 0.321051
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 12900: 0.407939
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# Minibatch loss at step 13000: 0.455487
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 13100: 0.417630
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 13200: 0.381628
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.6%
# Minibatch loss at step 13300: 0.446937
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.4%
# Minibatch loss at step 13400: 0.440614
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 13500: 0.487220
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 13600: 0.139723
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.5%
# Minibatch loss at step 13700: 0.127138
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# Minibatch loss at step 13800: 0.403018
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 13900: 0.310365
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.6%
# Minibatch loss at step 14000: 0.485193
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.6%
# Minibatch loss at step 14100: 0.396907
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 14200: 0.273963
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
# Minibatch loss at step 14300: 0.231412
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 14400: 0.579204
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Minibatch loss at step 14500: 0.255192
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 14600: 0.501304
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.6%
# Minibatch loss at step 14700: 0.271932
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
# Minibatch loss at step 14800: 0.190213
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Minibatch loss at step 14900: 0.550835
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 15000: 0.309763
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.7%
# Minibatch loss at step 15100: 0.563499
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 15200: 0.315742
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.5%
# Minibatch loss at step 15300: 0.508613
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 15400: 0.202368
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.8%
# Minibatch loss at step 15500: 0.516062
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.8%
# Minibatch loss at step 15600: 0.512041
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 15700: 0.323089
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 15800: 0.578718
# Minibatch accuracy: 84.4%
# Validation accuracy: 89.7%
# Minibatch loss at step 15900: 0.068063
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Minibatch loss at step 16000: 0.122624
# Minibatch accuracy: 96.9%
# Validation accuracy: 89.9%
# Test accuracy: 95.7%
