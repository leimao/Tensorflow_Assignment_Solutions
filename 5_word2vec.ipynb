# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  # Get the most frequent words and their frequences
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  # Make a word-frequency-rank dictionary
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'as', 'originated', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.869404
# Nearest to while: genesis, slave, scrupulous, actuality, lewis, provisional, headgear, ascetics,
# Nearest to many: schl, contours, charleston, purse, themselves, airport, ecowas, breakdancing,
# Nearest to called: surnamed, ignore, suspicious, wired, recommending, curried, hyperlinks, sprite,
# Nearest to which: uppermost, meeting, beforehand, alterations, kumamoto, evolution, croatian, spoiled,
# Nearest to of: teos, niebuhr, marcellus, epidemiological, subfamilies, resumed, instantiation, bums,
# Nearest to most: northwestern, tyrannosaurus, enthalpy, decaying, franchise, stench, passers, jes,
# Nearest to were: drug, mahavira, discreet, crafty, talent, ranching, november, microscope,
# Nearest to about: naturalised, endocrinology, bogus, converse, predate, drpg, rationalists, wishes,
# Nearest to zero: infirm, meister, hexer, alfons, scipione, desiring, rst, mx,
# Nearest to has: decreased, invocations, salvaged, arunachal, tug, northamptonshire, scheduling, sydney,
# Nearest to by: theatre, undesirable, paperwork, chamberlain, skate, wiener, oasis, yog,
# Nearest to also: keys, rapprochement, astronomical, cet, palace, oblast, problem, vee,
# Nearest to over: vide, rings, yemen, nagasaki, specie, vientiane, lupin, adjustment,
# Nearest to on: ajax, voss, daisy, airline, omri, ill, haaretz, fire,
# Nearest to the: acker, recounts, repaired, azad, deriving, ideas, harrisburg, brief,
# Nearest to as: practically, fraternal, experience, clash, village, contested, purcell, spreading,
# Average loss at step 2000: 4.348019
# Average loss at step 4000: 3.863147
# Average loss at step 6000: 3.783765
# Average loss at step 8000: 3.689236
# Average loss at step 10000: 3.617111
# Nearest to while: but, samael, slave, plough, genesis, simmons, nottingham, stephen,
# Nearest to many: some, railroads, dystrophy, gibbons, consonance, uralic, humus, these,
# Nearest to called: spines, suspicious, recommending, xvi, proteins, marvel, janeiro, curried,
# Nearest to which: this, it, that, also, still, there, codes, dix,
# Nearest to of: in, same, cooperstown, austrian, for, zog, chanted, on,
# Nearest to most: tubas, gules, northwestern, tyrannosaurus, more, furlong, franchise, ground,
# Nearest to were: are, was, had, have, rewriting, is, mores, talent,
# Nearest to about: naturalised, drpg, like, taxicab, only, rationalists, doorway, seasoned,
# Nearest to zero: eight, five, nine, seven, three, six, four, two,
# Nearest to has: had, have, is, was, password, litre, doubts, aquitaine,
# Nearest to by: yog, was, been, undesirable, in, forecasting, ibrd, unverifiable,
# Nearest to also: who, sometimes, it, encounters, which, originally, webcams, sod,
# Nearest to over: rings, jabberwocky, lupin, sanctification, blended, crichton, sidelines, auctions,
# Nearest to on: in, haaretz, peltier, adventist, with, devious, campy, dativus,
# Nearest to the: a, its, this, his, any, their, sit, crowther,
# Nearest to as: fraternal, thickness, hizballah, condemn, with, undercarriage, bouts, after,
# Average loss at step 12000: 3.603677
# Average loss at step 14000: 3.569390
# Average loss at step 16000: 3.408961
# Average loss at step 18000: 3.459569
# Average loss at step 20000: 3.539912
# Nearest to while: but, and, if, does, is, simmons, plough, when,
# Nearest to many: some, several, these, all, other, various, most, railroads,
# Nearest to called: suspicious, martians, spinoffs, plentiful, recommending, achieved, mycenae, swelled,
# Nearest to which: this, that, there, it, also, who, but, and,
# Nearest to of: for, zog, same, leno, macau, kinsella, cooperstown, in,
# Nearest to most: more, some, tubas, many, gig, scholastics, northwestern, ground,
# Nearest to were: are, was, had, have, rewriting, be, is, been,
# Nearest to about: naturalised, births, something, only, meditative, taxicab, theos, dynamics,
# Nearest to zero: five, six, seven, nine, three, four, eight, two,
# Nearest to has: had, have, is, was, afterthought, doubts, password, litre,
# Nearest to by: forecasting, been, be, in, yog, with, draconian, through,
# Nearest to also: which, now, who, never, often, sometimes, not, it,
# Nearest to over: provost, sanctification, recommendations, crichton, dabbled, lupin, iww, fushimi,
# Nearest to on: peltier, in, upon, at, devious, through, lookups, iceland,
# Nearest to the: their, its, a, this, any, his, crowther, each,
# Nearest to as: fraternal, enveloping, vicarious, racine, in, stimulate, stunt, single,
# Average loss at step 22000: 3.499205
# Average loss at step 24000: 3.490911
# Average loss at step 26000: 3.480575
# Average loss at step 28000: 3.476653
# Average loss at step 30000: 3.506297
# Nearest to while: but, when, although, if, and, is, however, was,
# Nearest to many: some, several, these, most, all, other, various, railroads,
# Nearest to called: suspicious, hop, containing, martians, janeiro, mycenae, dirty, spinoffs,
# Nearest to which: this, that, who, it, also, there, what, but,
# Nearest to of: from, for, zog, in, kinsella, rriais, actual, bedi,
# Nearest to most: some, more, many, tubas, gig, scholastics, all, northwestern,
# Nearest to were: are, was, had, have, been, being, rewriting, but,
# Nearest to about: on, naturalised, only, births, specific, accompanying, doorway, dynamics,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to has: had, have, is, was, litre, afterthought, steiner, password,
# Nearest to by: when, was, with, after, claudia, undesirable, during, from,
# Nearest to also: now, often, sometimes, who, which, still, it, never,
# Nearest to over: consecutively, sanctification, provost, debra, crichton, antiques, jabberwocky, folding,
# Nearest to on: upon, in, peltier, under, gaelic, through, about, devious,
# Nearest to the: its, their, his, a, some, an, crowther, many,
# Nearest to as: better, indexes, approved, racine, sky, spreading, alsatian, fraternal,
# Average loss at step 32000: 3.501101
# Average loss at step 34000: 3.493088
# Average loss at step 36000: 3.458349
# Average loss at step 38000: 3.300798
# Average loss at step 40000: 3.425354
# Nearest to while: although, but, when, though, however, if, where, and,
# Nearest to many: some, several, these, various, most, those, other, especially,
# Nearest to called: suspicious, hop, considered, lost, achieved, homophobic, named, dirty,
# Nearest to which: that, this, also, who, it, there, usually, often,
# Nearest to of: in, cryptic, for, cooperstown, from, zog, neared, where,
# Nearest to most: more, many, some, less, tubas, gig, scholastics, gules,
# Nearest to were: are, have, was, had, been, being, while, russians,
# Nearest to about: approximately, specific, on, accompanying, births, mccullough, recommendations, symphonic,
# Nearest to zero: seven, five, eight, nine, six, four, three, two,
# Nearest to has: had, have, was, is, lydians, steiner, dili, litre,
# Nearest to by: when, was, with, forecasting, cherbourg, pet, ray, mispronounced,
# Nearest to also: often, which, still, never, sometimes, now, who, usually,
# Nearest to over: sanctification, fincher, provost, folding, consecutively, between, splicing, crichton,
# Nearest to on: upon, peltier, adventist, at, in, lookups, leah, about,
# Nearest to the: its, this, each, another, a, his, promptly, their,
# Nearest to as: sped, cruzi, fraternal, kettle, tungsten, pillar, when, vicarious,
# Average loss at step 42000: 3.432402
# Average loss at step 44000: 3.455168
# Average loss at step 46000: 3.450863
# Average loss at step 48000: 3.353255
# Average loss at step 50000: 3.384956
# Nearest to while: when, although, however, though, but, where, after, if,
# Nearest to many: some, several, these, various, those, most, other, both,
# Nearest to called: suspicious, hop, referred, named, impotence, oxides, gauthier, hung,
# Nearest to which: that, this, also, usually, who, often, statically, what,
# Nearest to of: in, zog, and, including, daugava, bedi, cyrillic, same,
# Nearest to most: more, some, less, many, gig, sapphire, scholastics, jinn,
# Nearest to were: are, have, was, had, be, been, is, being,
# Nearest to about: approximately, symphonic, on, recommendations, births, specific, cyclic, deg,
# Nearest to zero: seven, five, eight, six, nine, four, three, two,
# Nearest to has: had, have, was, is, lydians, jaeger, contains, monrovia,
# Nearest to by: through, faire, was, forecasting, claudia, minuscule, draconian, with,
# Nearest to also: which, often, now, still, sometimes, never, officially, generally,
# Nearest to over: sanctification, cottages, through, rewarded, rodgers, folding, provost, recommendations,
# Nearest to on: upon, peltier, deserving, at, in, under, leah, within,
# Nearest to the: this, its, their, some, his, a, each, any,
# Nearest to as: fraternal, cease, clooney, better, racine, baptisms, fpss, himalayas,
# Average loss at step 52000: 3.435654
# Average loss at step 54000: 3.425177
# Average loss at step 56000: 3.444085
# Average loss at step 58000: 3.393320
# Average loss at step 60000: 3.394187
# Nearest to while: although, when, though, after, however, including, but, and,
# Nearest to many: some, several, these, various, both, most, especially, such,
# Nearest to called: suspicious, used, named, hop, considered, referred, consumes, known,
# Nearest to which: that, this, what, usually, however, who, these, it,
# Nearest to of: for, in, ely, chanted, same, bearer, whedon, including,
# Nearest to most: some, more, many, less, all, gig, especially, tubas,
# Nearest to were: are, was, had, have, been, although, including, those,
# Nearest to about: approximately, symphonic, recommendations, on, over, uncreated, happens, mistaking,
# Nearest to zero: five, eight, four, six, nine, seven, three, two,
# Nearest to has: had, have, was, is, contains, graduate, having, doubts,
# Nearest to by: through, with, yog, ids, denoting, compromises, momentarily, canadiens,
# Nearest to also: now, still, often, never, sometimes, generally, there, only,
# Nearest to over: between, around, through, across, consecutively, about, rewarded, into,
# Nearest to on: upon, through, devious, within, leah, peltier, commuted, ladakh,
# Nearest to the: its, their, a, each, this, any, some, blacklist,
# Nearest to as: racine, vicarious, baptisms, sped, nth, continuance, cladistic, instances,
# Average loss at step 62000: 3.241137
# Average loss at step 64000: 3.262465
# Average loss at step 66000: 3.399368
# Average loss at step 68000: 3.394630
# Average loss at step 70000: 3.354600
# Nearest to while: although, when, though, however, including, like, where, and,
# Nearest to many: some, several, various, these, all, most, especially, such,
# Nearest to called: named, referred, used, hop, suspicious, considered, consumes, defined,
# Nearest to which: that, this, what, but, also, usually, still, however,
# Nearest to of: include, like, including, in, for, kinsella, whedon, flightless,
# Nearest to most: more, less, many, some, especially, gig, particularly, rulebook,
# Nearest to were: are, was, have, had, be, been, aise, thermometer,
# Nearest to about: approximately, symphonic, that, over, recommendations, mistaking, lonesome, lett,
# Nearest to zero: five, four, six, eight, seven, nine, three, million,
# Nearest to has: had, have, is, was, contains, graduate, dili, steiner,
# Nearest to by: through, using, compromises, cherbourg, be, paperwork, as, yog,
# Nearest to also: still, now, never, often, which, sometimes, usually, generally,
# Nearest to over: around, through, consecutively, about, across, before, ccc, off,
# Nearest to on: upon, through, peltier, in, deserving, compel, within, devious,
# Nearest to the: their, its, a, this, our, an, these, wie,
# Nearest to as: stunt, racine, by, linseed, periodicals, indexes, nth, validated,
# Average loss at step 72000: 3.368109
# Average loss at step 74000: 3.349107
# Average loss at step 76000: 3.311613
# Average loss at step 78000: 3.350990
# Average loss at step 80000: 3.377327
# Nearest to while: although, though, when, however, after, but, or, and,
# Nearest to many: some, several, various, these, all, most, numerous, especially,
# Nearest to called: named, considered, referred, used, hop, known, designated, suspicious,
# Nearest to which: that, this, usually, who, wrestlemania, also, but, based,
# Nearest to of: in, including, daugava, actual, weiner, contraband, from, zog,
# Nearest to most: more, less, some, many, especially, particularly, scholastics, rulebook,
# Nearest to were: are, had, was, have, been, be, being, became,
# Nearest to about: approximately, symphonic, over, recommendations, wardrobe, mistaking, lett, seniority,
# Nearest to zero: seven, five, six, eight, four, nine, three, two,
# Nearest to has: had, have, is, was, having, relocating, graduate, contains,
# Nearest to by: through, using, when, claudia, yog, was, justifying, from,
# Nearest to also: still, now, never, often, sometimes, usually, which, generally,
# Nearest to over: around, between, about, consecutively, through, across, against, off,
# Nearest to on: upon, in, through, devious, peltier, deserving, compel, leah,
# Nearest to the: its, this, their, a, his, covens, deriving, interplay,
# Nearest to as: cruzi, destroyers, stunt, racine, became, baptisms, prefix, spreading,
# Average loss at step 82000: 3.407927
# Average loss at step 84000: 3.410007
# Average loss at step 86000: 3.392090
# Average loss at step 88000: 3.353691
# Average loss at step 90000: 3.361191
# Nearest to while: although, though, when, after, during, however, were, before,
# Nearest to many: some, several, various, these, all, most, numerous, those,
# Nearest to called: referred, named, considered, used, hop, known, suspicious, designated,
# Nearest to which: that, this, usually, what, who, also, wrestlemania, but,
# Nearest to of: including, daugava, in, for, current, actual, jref, following,
# Nearest to most: less, more, many, some, particularly, especially, wufei, all,
# Nearest to were: are, had, was, have, while, although, been, be,
# Nearest to about: approximately, symphonic, mistaking, recommendations, seniority, lett, over, lonesome,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to has: had, have, is, having, was, graduate, since, analgesic,
# Nearest to by: through, with, using, when, under, being, while, without,
# Nearest to also: still, never, often, now, sometimes, which, usually, generally,
# Nearest to over: around, through, between, off, against, into, across, actuated,
# Nearest to on: upon, peltier, through, devious, at, undertaker, compel, kilobit,
# Nearest to the: its, this, goodfellas, their, each, a, any, his,
# Nearest to as: stunt, sped, restorative, spreading, indexes, constrain, mckenna, saharan,
# Average loss at step 92000: 3.399936
# Average loss at step 94000: 3.247720
# Average loss at step 96000: 3.358340
# Average loss at step 98000: 3.236318
# Average loss at step 100000: 3.353584
# Nearest to while: although, though, when, however, and, after, before, if,
# Nearest to many: some, several, various, these, all, those, numerous, few,
# Nearest to called: referred, named, used, hop, considered, suspicious, attar, designated,
# Nearest to which: that, this, usually, what, who, these, however, often,
# Nearest to of: including, in, concerning, resuming, syngman, cooperstown, and, tswana,
# Nearest to most: more, less, especially, some, many, particularly, throughout, scholastics,
# Nearest to were: are, have, had, was, these, although, including, been,
# Nearest to about: approximately, symphonic, uncreated, around, recommendations, criollo, marriages, on,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to has: had, have, is, was, having, since, makes, linnean,
# Nearest to by: when, through, using, ids, penitence, ray, benford, minuscule,
# Nearest to also: never, sometimes, still, now, often, usually, generally, actually,
# Nearest to over: between, off, around, across, provost, through, into, within,
# Nearest to on: upon, peltier, in, through, at, under, within, around,
# Nearest to the: their, its, his, your, a, covens, our, her,
# Nearest to as: indexes, constrain, stunt, baptisms, linseed, pillar, sped, intimacy,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# ### Word2Vec Model - CBOW

# %% [markdown]
# Function to generate a training batch for the CBOW model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
    
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['term', 'originated', 'anarchism', 'a', 'term', 'originated', 'of', 'as']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %% [markdown]
# Train a CBOW model

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.076315
# Nearest to or: underrated, flashes, strict, infinities, tero, smallest, divergent, sandstorms,
# Nearest to there: subvert, carnation, pubic, ritual, ponder, sixty, exchangeable, mood,
# Nearest to with: transaction, forage, chupacabra, calculi, filmmaking, uighur, staves, ambitions,
# Nearest to four: resigns, plenary, junction, unravel, articulation, infidels, colorado, virginian,
# Nearest to system: jumblatt, lighting, hathaway, machinations, atacama, toto, tomlinson, transmitting,
# Nearest to people: lisbon, registers, badge, avalanche, highways, debugging, sirhan, neal,
# Nearest to has: serapis, kensington, corrie, weld, meg, gol, ona, retreated,
# Nearest to more: foreigners, mcclory, provoking, sqrt, dreamt, globes, trotskyism, bloodline,
# Nearest to over: retractable, cb, hurry, dorsal, drown, fon, abeyance, carte,
# Nearest to of: grassy, hillery, frazier, sgml, lick, calderas, stereoisomers, sagan,
# Nearest to be: hackett, dwarfs, spill, wanted, alteration, conserve, assures, quad,
# Nearest to three: recounts, jn, hussein, deco, materia, interchanges, emi, vectors,
# Nearest to state: revamp, landforms, dijkstra, majestic, idempotent, synge, guyer, permissible,
# Nearest to by: km, recession, myriad, rosa, uncompressed, belladonna, ellefson, convicts,
# Nearest to also: tley, everybody, unlikely, journ, vanir, latinized, disturbances, gig,
# Nearest to they: herbivores, pinocchio, sg, ar, strongest, bien, audiovisual, decca,
# Average loss at step 2000: 4.362265
# Average loss at step 4000: 3.863727
# Average loss at step 6000: 3.795589
# Average loss at step 8000: 3.685641
# Average loss at step 10000: 3.615950
# Nearest to or: and, trilobite, than, emmerdale, dogma, vulcan, fugazi, terrible,
# Nearest to there: it, he, they, not, tenant, which, subvert, opaque,
# Nearest to with: between, in, for, hilltop, when, after, horribly, following,
# Nearest to four: six, three, five, eight, seven, two, nine, zero,
# Nearest to system: lighting, bulges, irn, atacama, transmitting, antinomies, hathaway, levees,
# Nearest to people: badge, ega, those, hierarchies, debugging, depth, wealthiest, counterexample,
# Nearest to has: had, have, was, is, celera, kensington, sailing, currently,
# Nearest to more: havre, less, foreigners, schirra, levees, subfields, anions, emission,
# Nearest to over: abeyance, retractable, tishri, bridge, dorsal, demarcated, innsbruck, faceted,
# Nearest to of: in, on, grassy, at, for, manatees, and, pia,
# Nearest to be: have, by, manifesting, is, was, been, axum, avar,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to state: revamp, ocean, majestic, synge, flynn, dijkstra, regnal, erbium,
# Nearest to by: rosa, was, be, been, counterweight, as, from, coastal,
# Nearest to also: which, disturbances, cactus, not, hutton, inquisitors, now, bordering,
# Nearest to they: he, it, officiated, you, she, herbivores, there, not,
# Average loss at step 12000: 3.604997
# Average loss at step 14000: 3.576057
# Average loss at step 16000: 3.407212
# Average loss at step 18000: 3.456097
# Average loss at step 20000: 3.535328
# Nearest to or: and, than, for, without, with, clout, skilled, dogma,
# Nearest to there: they, it, he, which, raptor, she, blower, leiserson,
# Nearest to with: between, at, for, after, in, or, by, when,
# Nearest to four: six, three, five, eight, seven, two, nine, zero,
# Nearest to system: irn, lighting, transmitting, antinomies, hathaway, atacama, levees, teleology,
# Nearest to people: badge, those, wealthiest, depth, ega, years, latino, counterexample,
# Nearest to has: had, have, was, is, cellars, skyview, currently, celera,
# Nearest to more: less, schirra, havre, anions, subfields, guitarists, levees, further,
# Nearest to over: abeyance, pinning, retractable, hotbed, recruit, tishri, faceted, rioters,
# Nearest to of: for, grassy, normale, in, at, moravia, ffts, pia,
# Nearest to be: have, been, was, is, being, by, manifesting, not,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to state: revamp, iwerks, wendy, regnal, sram, golgi, ocean, mahmud,
# Nearest to by: rosa, csu, iberville, be, from, with, were, for,
# Nearest to also: which, now, not, it, often, usually, who, never,
# Nearest to they: he, there, we, you, it, who, officiated, she,
# Average loss at step 22000: 3.506020
# Average loss at step 24000: 3.486569
# Average loss at step 26000: 3.484055
# Average loss at step 28000: 3.479623
# Average loss at step 30000: 3.501712
# Nearest to or: and, recognises, ripple, powerpc, than, durch, without, trilobite,
# Nearest to there: they, it, he, still, she, this, which, we,
# Nearest to with: between, when, hilltop, by, in, forall, compute, regulations,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to system: systems, irn, transmitting, lighting, levees, nlds, judgment, code,
# Nearest to people: those, depth, badge, men, latino, years, hypoxic, hierarchies,
# Nearest to has: had, have, is, was, celera, scorers, having, kensington,
# Nearest to more: less, very, schirra, anions, havre, subfields, playboy, foreigners,
# Nearest to over: off, mv, demarcated, retractable, dop, tishri, yellowstone, recruit,
# Nearest to of: in, from, grassy, empowering, for, normale, rubinstein, companion,
# Nearest to be: have, been, is, manifesting, refer, were, was, are,
# Nearest to three: five, four, two, six, seven, eight, nine, zero,
# Nearest to state: revamp, states, sram, iwerks, forbids, synge, permissible, golgi,
# Nearest to by: with, exorbitant, was, belladonna, rosa, lech, yttrium, portraiture,
# Nearest to also: now, which, often, sometimes, generally, usually, originally, it,
# Nearest to they: we, there, he, you, it, who, not, officiated,
# Average loss at step 32000: 3.498200
# Average loss at step 34000: 3.495127
# Average loss at step 36000: 3.452236
# Average loss at step 38000: 3.307222
# Average loss at step 40000: 3.429830
# Nearest to or: and, than, muscat, maj, cray, ibiza, bertolucci, powerpc,
# Nearest to there: they, it, he, she, still, often, which, usually,
# Nearest to with: between, after, when, by, nancy, compute, hilltop, horribly,
# Nearest to four: six, five, eight, seven, three, two, nine, one,
# Nearest to system: systems, irn, lighting, musicbrainz, transmitting, mongoloids, corporation, atacama,
# Nearest to people: those, jungle, badge, depth, men, latino, natives, bloomberg,
# Nearest to has: had, have, was, is, ist, already, skyview, traditionally,
# Nearest to more: less, very, most, schirra, subfields, foreigners, decreases, chocolat,
# Nearest to over: through, off, mv, intercommunal, yellowstone, demarcated, incandescent, tishri,
# Nearest to of: in, normale, manatees, from, grassy, for, mishandling, dunbar,
# Nearest to be: have, been, was, being, are, were, refer, is,
# Nearest to three: five, two, four, seven, six, eight, nine, one,
# Nearest to state: states, occultists, revamp, godzilla, cn, government, efficiencies, atlantic,
# Nearest to by: formalised, with, be, when, was, pharisee, retrospective, loaned,
# Nearest to also: often, which, usually, sometimes, now, who, never, still,
# Nearest to they: we, you, there, he, it, she, who, these,
# Average loss at step 42000: 3.438831
# Average loss at step 44000: 3.457771
# Average loss at step 46000: 3.451473
# Average loss at step 48000: 3.352343
# Average loss at step 50000: 3.381349
# Nearest to or: and, bertolucci, cray, powerpc, than, broadsheet, apologised, surrealist,
# Nearest to there: they, it, she, he, still, we, which, often,
# Nearest to with: between, nancy, racehorse, transaction, mouths, hilltop, after, forall,
# Nearest to four: seven, six, five, three, eight, two, nine, zero,
# Nearest to system: systems, transmitting, irn, lighting, westerner, code, mongoloids, propounded,
# Nearest to people: men, members, those, women, counterexample, inhabitants, years, depth,
# Nearest to has: had, have, was, is, having, kensington, messiah, ist,
# Nearest to more: less, most, very, schirra, subfields, further, decreases, highly,
# Nearest to over: through, ajiva, off, mv, archaelogical, incandescent, into, tishri,
# Nearest to of: in, grassy, armouries, including, normale, kor, during, remaining,
# Nearest to be: have, been, refer, were, are, is, become, being,
# Nearest to three: four, six, seven, five, two, eight, nine, zero,
# Nearest to state: occultists, revamp, states, atlantic, sram, corroborated, guyer, wan,
# Nearest to by: through, under, fundraising, carne, from, counterweight, formalised, was,
# Nearest to also: which, often, now, still, usually, sometimes, never, typically,
# Nearest to they: we, he, there, you, it, she, these, who,
# Average loss at step 52000: 3.435989
# Average loss at step 54000: 3.429395
# Average loss at step 56000: 3.440033
# Average loss at step 58000: 3.400530
# Average loss at step 60000: 3.391198
# Nearest to or: and, than, thug, broadsheet, but, hinges, interchanged, like,
# Nearest to there: they, it, she, still, he, this, we, often,
# Nearest to with: between, iberville, when, by, doubted, racehorse, troll, including,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Nearest to system: systems, code, irn, lighting, process, transmitting, programming, migration,
# Nearest to people: men, those, members, women, christians, scholars, god, others,
# Nearest to has: had, have, is, was, contains, skyview, ist, having,
# Nearest to more: less, most, very, rather, further, larger, schirra, subfields,
# Nearest to over: through, intercommunal, between, yellowstone, about, apiece, required, incandescent,
# Nearest to of: for, in, like, grassy, normale, including, same, accusing,
# Nearest to be: been, have, refer, is, was, are, were, manifesting,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to state: revamp, guyer, occultists, corroborated, states, efficiencies, national, golgi,
# Nearest to by: through, molly, iberville, with, rosa, bipedal, vizier, was,
# Nearest to also: often, now, still, usually, sometimes, typically, never, which,
# Nearest to they: we, there, you, he, she, it, these, not,
# Average loss at step 62000: 3.240491
# Average loss at step 64000: 3.254020
# Average loss at step 66000: 3.406007
# Average loss at step 68000: 3.398435
# Average loss at step 70000: 3.350244
# Nearest to or: and, any, than, the, while, each, interchanged, every,
# Nearest to there: they, it, she, still, we, he, this, often,
# Nearest to with: between, among, compute, troll, while, by, gomorrah, when,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to system: systems, code, irn, raimi, process, lighting, transmitting, tius,
# Nearest to people: men, women, scholars, natives, members, god, critics, population,
# Nearest to has: had, have, is, was, contains, seems, skyview, reflexive,
# Nearest to more: less, most, very, further, rather, anions, too, faster,
# Nearest to over: through, about, considerable, required, intercommunal, beyond, yellowstone, mv,
# Nearest to of: including, include, and, in, opacity, mishandling, exact, concerning,
# Nearest to be: been, is, were, have, refer, become, are, was,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to state: states, guyer, revamp, occultists, government, corroborated, sram, wan,
# Nearest to by: through, rosa, from, counterweight, using, was, alongside, kapoor,
# Nearest to also: still, often, which, now, never, generally, sometimes, usually,
# Nearest to they: we, there, he, you, it, she, these, kohlberg,
# Average loss at step 72000: 3.380340
# Average loss at step 74000: 3.348365
# Average loss at step 76000: 3.314216
# Average loss at step 78000: 3.353111
# Average loss at step 80000: 3.377057
# Nearest to or: and, while, than, but, tall, jpg, zip, spreadsheet,
# Nearest to there: they, it, she, he, still, we, this, often,
# Nearest to with: between, during, merz, into, elicit, doubted, through, iberville,
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# Nearest to system: systems, code, restructure, irn, process, lighting, maule, dormitories,
# Nearest to people: men, women, natives, scholars, population, residents, jews, christians,
# Nearest to has: had, have, is, was, having, ist, bactria, seems,
# Nearest to more: less, very, most, highly, rather, faster, too, smaller,
# Nearest to over: about, through, between, intercommunal, incandescent, eccles, around, beyond,
# Nearest to of: including, in, grassy, arjuna, normale, rale, entire, argentinean,
# Nearest to be: been, have, refer, being, is, were, become, are,
# Nearest to three: four, six, five, seven, eight, two, nine, zero,
# Nearest to state: states, scriptural, guyer, revamp, sram, occultists, symmetries, corroborated,
# Nearest to by: through, formalised, bipedal, iberville, rosa, from, counterweight, ewes,
# Nearest to also: still, often, now, never, generally, actually, sometimes, typically,
# Nearest to they: we, he, there, you, she, it, who, these,
# Average loss at step 82000: 3.408847
# Average loss at step 84000: 3.411538
# Average loss at step 86000: 3.388915
# Average loss at step 88000: 3.355864
# Average loss at step 90000: 3.366273
# Nearest to or: and, than, maj, thug, nevsky, though, including, while,
# Nearest to there: they, it, she, still, he, we, now, which,
# Nearest to with: between, troll, hadiths, hilltop, in, compute, by, elicit,
# Nearest to four: five, seven, six, eight, three, nine, two, one,
# Nearest to system: systems, code, process, restructure, irn, hass, appoint, duchess,
# Nearest to people: men, women, jews, natives, residents, christians, god, population,
# Nearest to has: had, have, is, was, seems, having, contains, kensington,
# Nearest to more: less, very, most, highly, faster, rather, increasingly, too,
# Nearest to over: through, around, intercommunal, about, beyond, off, apiece, within,
# Nearest to of: including, for, following, dystrophy, nitrites, grassy, during, concerning,
# Nearest to be: been, have, being, was, is, become, refer, provide,
# Nearest to three: four, five, seven, two, eight, six, zero, nine,
# Nearest to state: states, scriptural, aruba, equates, government, sram, revamp, corroborated,
# Nearest to by: through, under, when, molly, hominy, without, formalised, reviewer,
# Nearest to also: now, still, often, never, which, sometimes, actually, generally,
# Nearest to they: we, he, you, there, she, it, kohlberg, yom,
# Average loss at step 92000: 3.399117
# Average loss at step 94000: 3.250847
# Average loss at step 96000: 3.357367
# Average loss at step 98000: 3.241942
# Average loss at step 100000: 3.355704
# Nearest to or: and, than, bertolucci, nevsky, tall, interchanged, sentencing, broadsheet,
# Nearest to there: they, it, she, we, he, still, usually, now,
# Nearest to with: between, including, hilltop, by, at, elicit, dash, racehorse,
# Nearest to four: seven, six, eight, five, nine, three, two, zero,
# Nearest to system: systems, code, process, restructure, irn, appoint, programming, tius,
# Nearest to people: men, women, jews, children, citizens, countries, them, residents,
# Nearest to has: had, have, is, was, having, since, jaya, contains,
# Nearest to more: less, most, very, faster, highly, enough, further, too,
# Nearest to over: through, around, about, tl, within, beyond, between, intercommunal,
# Nearest to of: including, goyen, original, from, and, in, to, scarborough,
# Nearest to be: been, have, is, refer, being, become, are, provide,
# Nearest to three: two, five, four, six, seven, eight, nine, zero,
# Nearest to state: states, guyer, corroborated, sram, symmetries, banana, federation, city,
# Nearest to by: without, formalised, through, including, under, with, lyc, when,
# Nearest to also: never, still, now, actually, sometimes, often, typically, traditionally,
# Nearest to they: we, there, you, he, she, it, i, these,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
